# %% [markdown]
# ## Importation ##

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import squareform
from sklearn import manifold
from sklearn.decomposition import PCA
from sklearn.metrics import euclidean_distances
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
import joblib

# %% [markdown]
# ## Data loading ##

# %%
data = pd.read_csv("data/data.csv")
data = shuffle(data, random_state=42)
data = data.head(5000)

# %% [markdown]
# ## Preprocessing ##

# %%
columns = ['valence', 'year', 'acousticness', 'artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo']

df = pd.DataFrame(data, columns=columns)

#drop_columns = ['valence', 'year', 'artists', 'duration_ms', 'explicit', 'id', 'key', 'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo']

drop_columns = ['artists', 'id', 'name', 'release_date']

scaler = MinMaxScaler()
df['year_scaled'] = scaler.fit_transform(df[['year']]) 
df['duration_ms'] = scaler.fit_transform(df[['duration_ms']])
df['key'] = scaler.fit_transform(df[['key']])
df['loudness'] = scaler.fit_transform(df[['loudness']])
df['popularity'] = scaler.fit_transform(df[['popularity']])
df['tempo'] = scaler.fit_transform(df[['tempo']])

ids = df['id'].tolist()
df = df.drop(columns=['id']+drop_columns, errors='ignore')




print(df)
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# 116368    0.910  1977        0.5000         0.894     0.071539  0.5210
# 161935    0.583  1976        0.9300         0.585     0.045802  0.2720
# 135703    0.647  1994        0.1570         0.878     0.045160  0.5200
# 112288    0.196  1957        0.9370         0.463     0.256456  0.2870
# 22        0.422  1921        0.9950         0.648     0.037883  0.0995
# ...         ...   ...           ...           ...          ...     ...
# 121224    0.612  2001        0.1840         0.533     0.046905  0.7030
# 166328    0.919  1999        0.0819         0.714     0.050976  0.8520
# 121731    0.345  2012        0.8820         0.215     0.041707  0.3190
# 59641     0.286  1942        0.9900         0.393     0.047238  0.0747
# 110754    0.633  1949        0.6410         0.449     0.019469  0.4510
#
#         explicit  instrumentalness       key  liveness  loudness  mode  \
# 116368         0          0.772000  0.363636     0.068  0.877197     1
# 161935         0          0.115000  1.000000     0.128  0.700759     0
# 135703         1          0.000000  0.636364     0.173  0.775469     1
# 112288         0          0.837000  0.000000     0.112  0.791036     0
# 22             0          0.846000  1.000000     0.112  0.595829     1
# ...          ...               ...       ...       ...       ...   ...
# 121224         0          0.000000  0.181818     0.101  0.889710     1
# 166328         0          0.000000  0.727273     0.285  0.885942     1
# 121731         0          0.000013  0.000000     0.228  0.771152     1
# 59641          0          0.078400  0.909091     0.102  0.678130     1
# 110754         0          0.247000  0.000000     0.139  0.759901     0
#
#         popularity  speechiness     tempo  year_scaled
# 116368    0.369565       0.0847  0.576127     0.565657
# 161935    0.282609       0.0802  0.409379     0.555556
# 135703    0.413043       0.4030  0.412287     0.737374
# 112288    0.141304       0.0363  0.848545     0.363636
# 22        0.000000       0.1050  0.327026     0.000000
# ...            ...          ...       ...          ...
# 121224    0.456522       0.0423  0.585014     0.808081
# 166328    0.434783       0.0565  0.418066     0.787879
# 121731    0.000000       0.0363  0.253731     0.919192
# 59641     0.000000       0.0321  0.460961     0.212121
# 110754    0.000000       0.0468  0.524905     0.282828
#
# [5000 rows x 16 columns]

# %% [markdown]
# ## Variables ##

# %%
inertia = []
silhouette_scores = []
K = list(range(2, 30))
random_state = 42

#X = shuffle(df, random_state=random_state)
# X = X[0:5000]
# print(X)
X = df

# %% [markdown]
# ## Determine Optimal K ##

# %%
print("Determine Optimal K")
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=random_state)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X, kmeans.labels_))
    print(f"value of k: {k}")

# #Plot the Elbow Method
# plt.figure(figsize=(10, 5))
# plt.plot(K, inertia, 'bo-')
# plt.xlabel('Number of clusters')
# plt.ylabel('Inertia')
# plt.title('Elbow Method For Optimal k')
# plt.show()
# 
# #Plot the Silhouette Method
# plt.figure(figsize=(10, 5))
# plt.plot(K, silhouette_scores, 'bo-')
# plt.xlabel('Number of clusters')
# plt.ylabel('Silhouette Score')
# plt.title('Silhouette Method For Optimal k')
# plt.show()

# Determine the optimal number of clusters
optimal_k = 0
for i in range(len(inertia)):
    if i == len(inertia) - 1 and optimal_k == 0:
        optimal_k = K[i]
    elif i != 0:
        print(f"dif = {abs(inertia[i-1] - inertia[i])}")
        print(f"inertia[{i}]*0.1 = {inertia[i] *0.1}")
        if abs(inertia[i-1] - inertia[i]) < inertia[i]*0.1:
            optimal_k = K[i]
            break

print(f"The optimal number of clusters is {optimal_k}")


kmean = KMeans(n_clusters=optimal_k, random_state=random_state)
kmean.fit(X)

joblib.dump(kmean, 'kmean_model.pkl')

clusters = kmean.predict(X)

with open('ids.txt', 'w') as file:
    for i in range(len(ids)):
        file.write(f"{ids[i]} {clusters[i]}\n")

# Plot the data points with their cluster
# plt.figure(figsize=(10, 7))
# plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=clusters, cmap='viridis', marker='o', edgecolor='k', s=50)
# plt.title('Data points and their clusters')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.show()

# %matplotlib notebook
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# ax.scatter(X.iloc[:, 0], X.iloc[:, 1], X.iloc[:, 2], c=clusters, cmap='viridis', marker='o', edgecolor='k', s=50)
# ax.set_title('Data points and their clusters')
# ax.set_xlabel('Feature 1')
# ax.set_ylabel('Feature 2')
# ax.set_zlabel('Feature 3')
# plt.show()
# Out:
# Determine Optimal K
# value of k: 2
# value of k: 3
# value of k: 4
# value of k: 5
# value of k: 6
# value of k: 7
# value of k: 8
# value of k: 9
# value of k: 10
# value of k: 11
# value of k: 12
# value of k: 13
# value of k: 14
# value of k: 15
# value of k: 16
# value of k: 17
# value of k: 18
# value of k: 19
# value of k: 20
# value of k: 21
# value of k: 22
# value of k: 23
# value of k: 24
# value of k: 25
# value of k: 26
# value of k: 27
# value of k: 28
# value of k: 29
# dif = 493088.67954788473
# inertia[1]*0.1 = 41925.943967740845
# dif = 165534.65045790264
# inertia[2]*0.1 = 25372.47892195058
# dif = 93518.77063569566
# inertia[3]*0.1 = 16020.601858381015
# dif = 50298.086436833706
# inertia[4]*0.1 = 10990.793214697644
# dif = 25175.118717286925
# inertia[5]*0.1 = 8473.28134296895
# dif = 20755.84555165325
# inertia[6]*0.1 = 6397.696787803626
# dif = 11134.858835336017
# inertia[7]*0.1 = 5284.210904270024
# dif = 10142.165385625434
# inertia[8]*0.1 = 4269.99436570748
# dif = 5707.813061608453
# inertia[9]*0.1 = 3699.213059546635
# dif = 6666.421982184682
# inertia[10]*0.1 = 3032.5708613281668
# dif = 3899.934348447812
# inertia[11]*0.1 = 2642.5774264833854
# dif = 2710.6973029663204
# inertia[12]*0.1 = 2371.5076961867535
# dif = 2561.71743766261
# inertia[13]*0.1 = 2115.3359524204925
# dif = 1103.6984181906846
# inertia[14]*0.1 = 2004.966110601424
# The optimal number of clusters is 16

# %% [markdown]
# ## ma valeur ##

# %%
my_value = [0.85, 0.51, 0.10, 0.9, 0.14,0,0.74,0.56,0.1,0,0.3,0.75,0.6,0,0.8, 0.1]

# %% [markdown]
# ## Preciction ##

# %%
elements_in_cluster = []

def get_cluster_info(data_point, elements_in_cluster):
    # Ensure data_point is a DataFrame with the same columns as the original data
    
    data_point_df = pd.DataFrame([data_point], columns=df.columns)    

    # Predict the cluster for the given data point
    data_point_cluster = kmean.predict(data_point_df)[0]
    
    #elements_in_cluster = X[clusters == data_point_cluster]
    for index in range(len(clusters)):
        if clusters[index] == data_point_cluster:
            print(f"index: {index} et id: {ids[index]}")
            elements_in_cluster.append(ids[index])


    return data_point_cluster

data_point = my_value
cluster = get_cluster_info(data_point, elements_in_cluster)
print(f"Elements in cluster {cluster}:\n{elements_in_cluster}")
# Out:
# index: 4 et id: 0SK1upzAP6NvIgF0uGh6z2
# index: 72 et id: 10NokhLWqxzi6Qg10vcGQ5
# index: 75 et id: 6Sza4f5kWjsfIAxzThgPRa
# index: 120 et id: 6wNFn9EiP2oa9fxV6FgARk
# index: 268 et id: 4U4z1JcAL4f3E4YYitRyMX
# index: 438 et id: 13ZrfHNfVnzIZlXyetXke3
# index: 455 et id: 7JqEsyJDSlGjg95DDk1Q71
# index: 514 et id: 6tdZSytSJjP1hxkRBD8gVA
# index: 605 et id: 5cIES4mu3rdDSNQ7aluQKz
# index: 664 et id: 7agPeo1jNiA5OEXGFDzl7I
# index: 667 et id: 5waV2tHn9zLn6ot0wzIw9c
# index: 701 et id: 5jzNqmHq9b7xxr6GGFpFwm
# index: 752 et id: 0m2zzAhHz4DZHXYh6m0h0e
# index: 762 et id: 0YFDGOIR9ubDqWCvsUQKY0
# index: 790 et id: 5YZpAH2jWtOOvbe1jv936Q
# index: 835 et id: 0yblbywxeP28xmOxSrcUYk
# index: 844 et id: 1Lbm5IC3QN56LtoyvQMUpH
# index: 866 et id: 6XSm7HngoGvLlOViuMQfAW
# index: 951 et id: 34rdVyVGI2u6I0tNWc8v0Y
# index: 1044 et id: 5xoKOYyS2kCzxb9docXLaY
# index: 1075 et id: 75FDlSK7dHKU6TtMGrBFXK
# index: 1155 et id: 6q9IP7wbfpocUiOEGvQqCZ
# index: 1318 et id: 2paUNK969mjN9A8cXLnHfp
# index: 1371 et id: 4ywiiUqjEvx8RufPznNY8K
# index: 1397 et id: 2ASfkMyqqICcBsauldmXmr
# index: 1400 et id: 5p09ipvLSCmKEcE1Pt7lFu
# index: 1498 et id: 4TZ5xHacg417VxJC2qkSdt
# index: 1583 et id: 0puMN7VeWf9uT8QU5Waazm
# index: 1601 et id: 6bTkrQHnJUXAQtIITRhTg5
# index: 1622 et id: 4fFzWSYKJacbJwnPElOoHA
# index: 1670 et id: 5hsVJEsoRAAIgcekezkOK2
# index: 1673 et id: 65nWLObU0ZFoIb4VII3TmN
# index: 1718 et id: 4a2F03DV04cDPFUARAAG9T
# index: 1727 et id: 18iy13trBcZZrzy6H6qZdA
# index: 1744 et id: 4IdRlWOb2JA9pxKwuLtbFn
# index: 1745 et id: 1agQgiViJVJrONfuBVGck6
# index: 1753 et id: 0Uw7D9i1mjDuW3ZphqiVgz
# index: 1792 et id: 4lEHJCjkNJwqdEmYablJeF
# index: 1805 et id: 5Bk13n28rlG7GYCKDshsQM
# index: 1882 et id: 46hnjNrgeO4qnUdfSva5XI
# index: 1889 et id: 22pXPBKNNtdN5HFpknUePa
# index: 1899 et id: 4plrXmyIaAWqa00evTfmvc
# index: 1954 et id: 0QjKrBoL45QoHSORFamooh
# index: 1956 et id: 2cODstPu4nOAIFfwnvNEwx
# index: 2004 et id: 1QRYGTxFGhKzix98AHnBQC
# index: 2062 et id: 3fHgV9OfktqOegAvEP6zlv
# index: 2084 et id: 21010f0ucoaLEEn4khQKZb
# index: 2122 et id: 4rHwSgSxRM2UDWEZD7BOoa
# index: 2182 et id: 1DMuD0CaT8fJxx5pIbRJzP
# index: 2189 et id: 1QXEKqhje8QucDzcGRVl4r
# index: 2213 et id: 18BvzCRC1jeAsj1U70YuRy
# index: 2214 et id: 6u3m2bP3RHNYVLH4Dh4M7T
# index: 2314 et id: 6C0k7xIhe3DakNTtSuVfnz
# index: 2339 et id: 7KF9CnhBfUeiF0koEdEh1g
# index: 2390 et id: 5IsynXMWRxrrKQqntIzVPz
# index: 2402 et id: 18NiVMY4Fz6MjnhrX8xFiM
# index: 2496 et id: 3VPirEcISU7rbDYX5lLJXb
# index: 2629 et id: 0GkpS6KjxFsNt61hOpB2j9
# index: 2688 et id: 3YTfuE6FDdVfC1ImwUrbL6
# index: 2732 et id: 7yCTnp1QXyTe6zX6YLi9MB
# index: 2934 et id: 4IUls53mx64sfeX1LBxCM5
# index: 3005 et id: 4Q3wWaqpqAnbwxsRh2aqdw
# index: 3072 et id: 6IuWOf8fl5nCyMdrdIWpUg
# index: 3076 et id: 32tFopk1tg3G3tMN9QE5E7
# index: 3281 et id: 4m1Th0JSQkevDsHiOpoxlQ
# index: 3344 et id: 2zFWLv60Tyz6D7SUQUNZtH
# index: 3383 et id: 0zwQ9BjnBlzot06OgFBn4K
# index: 3389 et id: 3tlygdsn8Jl6D0XA7RRslx
# index: 3400 et id: 4ZUsU6KfJumcoxx5CVSh5a
# index: 3463 et id: 2TFZPFg3rSaN1Ze0QFkPHL
# index: 3504 et id: 3uwnTgLWwBnkcC7pt7iqyS
# index: 3515 et id: 4peWT0oTDiJX8Pezx41qv8
# index: 3545 et id: 5K6eShQXgL65FitgXDl7sp
# index: 3549 et id: 48uWNLgQTIuI2FKRDWrWus
# index: 3560 et id: 0jiH6Bf3OOm36ubMWZ0Sr5
# index: 3604 et id: 4vLc0mWLQ8S8T6XR5Us97h
# index: 3662 et id: 2B0QcTyp3OIwxpQNqyi9xP
# index: 3707 et id: 4A39I4HjveytQdAkqObfoq
# index: 3754 et id: 39cC4IpoOurViWwD0xvzTP
# index: 3861 et id: 5huNRasbP9KCRtUSnsumWr
# index: 3885 et id: 6fkBZ0rjDb0HVlCyP1JMDe
# index: 3983 et id: 3mF2yzcl2Oo5y9JnpTNA3p
# index: 3999 et id: 5l8QuknVv6Show2Qi155gQ
# index: 4001 et id: 6V2ySkQ72sK6ULJO0k68of
# index: 4018 et id: 6bbw42aj4GYx9TGsMBSknN
# index: 4049 et id: 7kbJsn9BmMpH6lMTCaCJPR
# index: 4188 et id: 7D0v2vvXNGNV6w3qQsWQxA
# index: 4266 et id: 4WPL5dkeBbiLGBmtoKfXDk
# index: 4321 et id: 7FozfNBwWkeqPMJzDYqeuc
# index: 4357 et id: 4xDAzKsPZg7kMOhsnXHOO7
# index: 4363 et id: 4iy1fsAHBgR2STJjPDhjY2
# index: 4377 et id: 3grfvaO0LT8pk4g4ZAfU83
# index: 4472 et id: 74Yz2CG84oZnqjlfunMBYE
# index: 4557 et id: 3MUeRkKpLxxyRFzqMTj1HY
# index: 4594 et id: 2HD6jTefKllTXBN0r16ZPa
# index: 4604 et id: 0XYOh3EWZn83nhpgvydsF7
# index: 4620 et id: 1MJeNrEs6ChFUzB8M43V8Q
# index: 4645 et id: 6kB1oM8freauJGNKn9G5Ea
# index: 4649 et id: 0WjVVTbdA4vay91MofVEtQ
# index: 4749 et id: 3XHUxnjmA15lbMDcGYiWwZ
# index: 4785 et id: 6hb5RUltHGRqgaC4H4iLfn
# index: 4827 et id: 4MMJVh055Vo5yA83OtvMGM
# index: 4876 et id: 6kPXZEptkVzC1BN7dpoBb3
# index: 4963 et id: 0L3y8QdEPQhzBjmxZqagF1
# Elements in cluster 4:
# ['0SK1upzAP6NvIgF0uGh6z2', '10NokhLWqxzi6Qg10vcGQ5', '6Sza4f5kWjsfIAxzThgPRa', '6wNFn9EiP2oa9fxV6FgARk', '4U4z1JcAL4f3E4YYitRyMX', '13ZrfHNfVnzIZlXyetXke3', '7JqEsyJDSlGjg95DDk1Q71', '6tdZSytSJjP1hxkRBD8gVA', '5cIES4mu3rdDSNQ7aluQKz', '7agPeo1jNiA5OEXGFDzl7I', '5waV2tHn9zLn6ot0wzIw9c', '5jzNqmHq9b7xxr6GGFpFwm', '0m2zzAhHz4DZHXYh6m0h0e', '0YFDGOIR9ubDqWCvsUQKY0', '5YZpAH2jWtOOvbe1jv936Q', '0yblbywxeP28xmOxSrcUYk', '1Lbm5IC3QN56LtoyvQMUpH', '6XSm7HngoGvLlOViuMQfAW', '34rdVyVGI2u6I0tNWc8v0Y', '5xoKOYyS2kCzxb9docXLaY', '75FDlSK7dHKU6TtMGrBFXK', '6q9IP7wbfpocUiOEGvQqCZ', '2paUNK969mjN9A8cXLnHfp', '4ywiiUqjEvx8RufPznNY8K', '2ASfkMyqqICcBsauldmXmr', '5p09ipvLSCmKEcE1Pt7lFu', '4TZ5xHacg417VxJC2qkSdt', '0puMN7VeWf9uT8QU5Waazm', '6bTkrQHnJUXAQtIITRhTg5', '4fFzWSYKJacbJwnPElOoHA', '5hsVJEsoRAAIgcekezkOK2', '65nWLObU0ZFoIb4VII3TmN', '4a2F03DV04cDPFUARAAG9T', '18iy13trBcZZrzy6H6qZdA', '4IdRlWOb2JA9pxKwuLtbFn', '1agQgiViJVJrONfuBVGck6', '0Uw7D9i1mjDuW3ZphqiVgz', '4lEHJCjkNJwqdEmYablJeF', '5Bk13n28rlG7GYCKDshsQM', '46hnjNrgeO4qnUdfSva5XI', '22pXPBKNNtdN5HFpknUePa', '4plrXmyIaAWqa00evTfmvc', '0QjKrBoL45QoHSORFamooh', '2cODstPu4nOAIFfwnvNEwx', '1QRYGTxFGhKzix98AHnBQC', '3fHgV9OfktqOegAvEP6zlv', '21010f0ucoaLEEn4khQKZb', '4rHwSgSxRM2UDWEZD7BOoa', '1DMuD0CaT8fJxx5pIbRJzP', '1QXEKqhje8QucDzcGRVl4r', '18BvzCRC1jeAsj1U70YuRy', '6u3m2bP3RHNYVLH4Dh4M7T', '6C0k7xIhe3DakNTtSuVfnz', '7KF9CnhBfUeiF0koEdEh1g', '5IsynXMWRxrrKQqntIzVPz', '18NiVMY4Fz6MjnhrX8xFiM', '3VPirEcISU7rbDYX5lLJXb', '0GkpS6KjxFsNt61hOpB2j9', '3YTfuE6FDdVfC1ImwUrbL6', '7yCTnp1QXyTe6zX6YLi9MB', '4IUls53mx64sfeX1LBxCM5', '4Q3wWaqpqAnbwxsRh2aqdw', '6IuWOf8fl5nCyMdrdIWpUg', '32tFopk1tg3G3tMN9QE5E7', '4m1Th0JSQkevDsHiOpoxlQ', '2zFWLv60Tyz6D7SUQUNZtH', '0zwQ9BjnBlzot06OgFBn4K', '3tlygdsn8Jl6D0XA7RRslx', '4ZUsU6KfJumcoxx5CVSh5a', '2TFZPFg3rSaN1Ze0QFkPHL', '3uwnTgLWwBnkcC7pt7iqyS', '4peWT0oTDiJX8Pezx41qv8', '5K6eShQXgL65FitgXDl7sp', '48uWNLgQTIuI2FKRDWrWus', '0jiH6Bf3OOm36ubMWZ0Sr5', '4vLc0mWLQ8S8T6XR5Us97h', '2B0QcTyp3OIwxpQNqyi9xP', '4A39I4HjveytQdAkqObfoq', '39cC4IpoOurViWwD0xvzTP', '5huNRasbP9KCRtUSnsumWr', '6fkBZ0rjDb0HVlCyP1JMDe', '3mF2yzcl2Oo5y9JnpTNA3p', '5l8QuknVv6Show2Qi155gQ', '6V2ySkQ72sK6ULJO0k68of', '6bbw42aj4GYx9TGsMBSknN', '7kbJsn9BmMpH6lMTCaCJPR', '7D0v2vvXNGNV6w3qQsWQxA', '4WPL5dkeBbiLGBmtoKfXDk', '7FozfNBwWkeqPMJzDYqeuc', '4xDAzKsPZg7kMOhsnXHOO7', '4iy1fsAHBgR2STJjPDhjY2', '3grfvaO0LT8pk4g4ZAfU83', '74Yz2CG84oZnqjlfunMBYE', '3MUeRkKpLxxyRFzqMTj1HY', '2HD6jTefKllTXBN0r16ZPa', '0XYOh3EWZn83nhpgvydsF7', '1MJeNrEs6ChFUzB8M43V8Q', '6kB1oM8freauJGNKn9G5Ea', '0WjVVTbdA4vay91MofVEtQ', '3XHUxnjmA15lbMDcGYiWwZ', '6hb5RUltHGRqgaC4H4iLfn', '4MMJVh055Vo5yA83OtvMGM', '6kPXZEptkVzC1BN7dpoBb3', '0L3y8QdEPQhzBjmxZqagF1']
